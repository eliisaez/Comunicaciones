# %%
import datetime
import json
import urllib.request

def time_converter(time):
    converted_time = datetime.datetime.fromtimestamp(
        int(time)
    ).strftime('%I:%M %p')
    return converted_time

def url_builder1(city):
    user_api = 'ab2352d806b61edda7497db5c01e42e1'  # Obtain yours form: http://openweathermap.org/
    unit = 'metric'  # For Fahrenheit use imperial, for Celsius use metric, and the default is Kelvin.
    api = 'http://api.openweathermap.org/data/2.5/weather?q='     # Search for your city ID here: http://bulk.openweathermap.org/sample/city.list.json.gz
    full_api_url = api + str(city) + '&mode=json&units=' + unit + '&APPID=' + user_api
    #print(full_api_url)
    return full_api_url

def data_fetch(full_api_url):
    url = urllib.request.urlopen(full_api_url)
    output = url.read().decode('utf-8')
    raw_api_dict = json.loads(output)
    url.close()
    #print(raw_api_dict)
    return raw_api_dict

if __name__ == '__main__':
    try:
        now=datetime.datetime.now()
        city= ['Elche,ES', 'Denia', 'Alicante', 'Javea',  'Moraira', 'Calpe', 'Tenerife', 'Bisau']
        buendia= []
        for c in city: 
          datos=data_fetch(url_builder1(c))
          print('En la ciudad de', c, 'ahora mismo (', now, ') hace este tiempo: ')
          #print(datos)
          #print(now)
          #print(datos['weather']['description'])
          for key in datos['main']:
            if key== 'feels_like':
              print( "Sensación de temperatura de:", datos['main'][key])
              if datos['main'][key]>20:
                 buendia.append(c)


          for key in datos['clouds']:
            print("Porcentaje de nubes:", datos['clouds'][key])
            if datos['clouds'][key]>= 60:
               print("Está bastante nublado", c, "...")
            else:
              print("Día perfecto para ir a", c, "!!")
          print("\n")

        if not buendia: 
          print("No hay ningun sitio en tu zona para ir a la playa...")
        else: 
          print("¡Para un día de playa perfecto tienes estas posibilidades! \n")
          for i in buendia: 
            print(i," ")
         # for key in datos['sys']:
          #  print(key, ":", datos['sys'][key])
          #print(time_converter(1612681284))
          #print(time_converter(datos['sys']['sunrise']))
          #print(time_converter(datos['sys']['sunset']))
    
    except IOError:
        print('error')
# Out:
# En la ciudad de Elche,ES ahora mismo ( 2022-03-04 17:21:08.126027 ) hace este tiempo:
# Sensación de temperatura de: 12.57
# Porcentaje de nubes: 75
# Está bastante nublado Elche,ES ...
#
#
# En la ciudad de Denia ahora mismo ( 2022-03-04 17:21:08.126027 ) hace este tiempo:
# Sensación de temperatura de: 13.25
# Porcentaje de nubes: 79
# Está bastante nublado Denia ...
#
#
# En la ciudad de Alicante ahora mismo ( 2022-03-04 17:21:08.126027 ) hace este tiempo:
# Sensación de temperatura de: 13.25
# Porcentaje de nubes: 75
# Está bastante nublado Alicante ...
#
#
# En la ciudad de Javea ahora mismo ( 2022-03-04 17:21:08.126027 ) hace este tiempo:
# Sensación de temperatura de: 13.22
# Porcentaje de nubes: 82
# Está bastante nublado Javea ...
#
#
# En la ciudad de Moraira ahora mismo ( 2022-03-04 17:21:08.126027 ) hace este tiempo:
# Sensación de temperatura de: 13.33
# Porcentaje de nubes: 81
# Está bastante nublado Moraira ...
#
#
# ...
